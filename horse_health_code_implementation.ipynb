# %%
#Importing the required libraries and loading the dataset
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
#Load the dataset and Display First and Last 3 rows of the dataset
df = pd.read_csv("https://raw.githubusercontent.com/salemprakash/EDA/main/Data/horse.csv")
print(df.head(3))
print(df.tail(3))
# Out:
#   surgery    age  hospital_number  rectal_temp  pulse  respiratory_rate  \
# 0      no  adult           530101         38.5   66.0              28.0
# 1     yes  adult           534817         39.2   88.0              20.0
# 2      no  adult           530334         38.3   40.0              24.0
#
#   temp_of_extremities peripheral_pulse mucous_membrane capillary_refill_time  \
# 0                cool          reduced             NaN            more_3_sec
# 1                 NaN              NaN   pale_cyanotic            less_3_sec
# 2              normal           normal       pale_pink            less_3_sec
#
#    ... packed_cell_volume total_protein abdomo_appearance abdomo_protein  \
# 0  ...               45.0           8.4               NaN            NaN
# 1  ...               50.0          85.0            cloudy            2.0
# 2  ...               33.0           6.7               NaN            NaN
#
#       outcome  surgical_lesion lesion_1 lesion_2  lesion_3  cp_data
# ...

# %%
# Check dataset dimensions
print("Number of Rows:", df.shape[0])
print("Number of Columns:", df.shape[1])
# Out:
# Number of Rows: 299
# Number of Columns: 28

# %%
# Summary statistics
print(df.describe())
pd.isna(df).any()
# Out:
#        hospital_number  rectal_temp       pulse  respiratory_rate  \
# count     2.990000e+02   239.000000  275.000000        241.000000
# mean      1.087733e+06    38.168619   72.000000         30.460581
# std       1.532032e+06     0.733744   28.646219         17.666102
# min       5.184760e+05    35.400000   30.000000          8.000000
# 25%       5.289040e+05    37.800000   48.000000         18.000000
# 50%       5.303010e+05    38.200000   64.000000         25.000000
# 75%       5.347360e+05    38.500000   88.000000         36.000000
# max       5.305629e+06    40.800000  184.000000         96.000000
#
#        nasogastric_reflux_ph  packed_cell_volume  total_protein  \
# count              53.000000          270.000000     266.000000
# mean                4.707547           46.307407      24.274436
# std                 1.982311           10.436743      27.364194
# min                 1.000000           23.000000       3.300000
# ...

# %%
#Check the data types of each column
df.dtypes
# Out:
# surgery                   object
# age                       object
# hospital_number            int64
# rectal_temp              float64
# pulse                    float64
# respiratory_rate         float64
# temp_of_extremities       object
# peripheral_pulse          object
# mucous_membrane           object
# capillary_refill_time     object
# pain                      object
# peristalsis               object
# abdominal_distention      object
# nasogastric_tube          object
# nasogastric_reflux        object
# nasogastric_reflux_ph    float64
# rectal_exam_feces         object
# abdomen                   object
# packed_cell_volume       float64
# total_protein            float64
# abdomo_appearance         object
# abdomo_protein           float64
# outcome                   object
# surgical_lesion           object
# lesion_1                   int64
# lesion_2                   int64
# lesion_3                   int64
# cp_data                   object
# dtype: object

# %%
#Check for null values
df.notnull()
# Out:
#      surgery   age  hospital_number  rectal_temp  pulse  respiratory_rate  \
# 0       True  True             True         True   True              True
# 1       True  True             True         True   True              True
# 2       True  True             True         True   True              True
# 3       True  True             True         True   True              True
# 4       True  True             True         True   True              True
# ..       ...   ...              ...          ...    ...               ...
# 294     True  True             True        False   True              True
# 295     True  True             True         True   True              True
# 296     True  True             True         True   True              True
# 297     True  True             True         True   True              True
# 298     True  True             True         True   True              True
#
#      temp_of_extremities  peripheral_pulse  mucous_membrane  \
# ...

# %%
#Total no. of null values
df.isnull().sum()
# Out:
# surgery                    0
# age                        0
# hospital_number            0
# rectal_temp               60
# pulse                     24
# respiratory_rate          58
# temp_of_extremities       56
# peripheral_pulse          69
# mucous_membrane           47
# capillary_refill_time     32
# pain                      55
# peristalsis               44
# abdominal_distention      56
# nasogastric_tube         104
# nasogastric_reflux       106
# nasogastric_reflux_ph    246
# rectal_exam_feces        102
# abdomen                  118
# packed_cell_volume        29
# total_protein             33
# abdomo_appearance        165
# abdomo_protein           198
# outcome                    0
# surgical_lesion            0
# lesion_1                   0
# lesion_2                   0
# lesion_3                   0
# cp_data                    0
# dtype: int64

# %%
# Percentage of missing values per column
missing_percent = df.isnull().mean() * 100
missing_percent.sort_values(ascending=False)
# Out:
# nasogastric_reflux_ph    82.274247
# abdomo_protein           66.220736
# abdomo_appearance        55.183946
# abdomen                  39.464883
# nasogastric_reflux       35.451505
# nasogastric_tube         34.782609
# rectal_exam_feces        34.113712
# peripheral_pulse         23.076923
# rectal_temp              20.066890
# respiratory_rate         19.397993
# temp_of_extremities      18.729097
# abdominal_distention     18.729097
# pain                     18.394649
# mucous_membrane          15.719064
# peristalsis              14.715719
# total_protein            11.036789
# capillary_refill_time    10.702341
# packed_cell_volume        9.698997
# pulse                     8.026756
# lesion_2                  0.000000
# surgical_lesion           0.000000
# lesion_3                  0.000000
# lesion_1                  0.000000
# surgery                   0.000000
# outcome                   0.000000
# age                       0.000000
# hospital_number           0.000000
# ...

# %%
# Drop columns with more than 50% missing values
threshold = 0.5  # 50%
df = df.loc[:, df.isnull().mean() < threshold]

print("Remaining columns:", df.shape[1])
print(df)
# Out:
# Remaining columns: 25
#     surgery    age  hospital_number  rectal_temp  pulse  respiratory_rate  \
# 0        no  adult           530101         38.5   66.0              28.0
# 1       yes  adult           534817         39.2   88.0              20.0
# 2        no  adult           530334         38.3   40.0              24.0
# 3       yes  young          5290409         39.1  164.0              84.0
# 4        no  adult           530255         37.3  104.0              35.0
# ..      ...    ...              ...          ...    ...               ...
# 294     yes  adult           533886          NaN  120.0              70.0
# 295      no  adult           527702         37.2   72.0              24.0
# 296     yes  adult           529386         37.5   72.0              30.0
# 297     yes  adult           530612         36.5  100.0              24.0
# 298     yes  adult           534618         37.2   40.0              20.0
#
# ...

# %%
#Columns with missing values after dropping columns
df.isnull().sum()[df.isnull().sum() > 0]
# Out:
# rectal_temp               60
# pulse                     24
# respiratory_rate          58
# temp_of_extremities       56
# peripheral_pulse          69
# mucous_membrane           47
# capillary_refill_time     32
# pain                      55
# peristalsis               44
# abdominal_distention      56
# nasogastric_tube         104
# nasogastric_reflux       106
# rectal_exam_feces        102
# abdomen                  118
# packed_cell_volume        29
# total_protein             33
# dtype: int64

# %%
#Replacing missing data in both numerical and categorical data columns
numeric_cols = df.select_dtypes(include=['number']).columns
categorical_cols = df.select_dtypes(include=['object']).columns

# %%
#Replacing numerical columns with Mean
for col in numeric_cols:
    df[col].fillna(df[col].mean(), inplace=True)
# Out:
# C:\Users\mukhe\AppData\Local\Temp\ipykernel_17324\2944886569.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mean(), inplace=True)

# %%
#Replacing categorical columns with Mode
for col in categorical_cols:
    df[col].fillna(df[col].mode()[0], inplace=True)
# Out:
# C:\Users\mukhe\AppData\Local\Temp\ipykernel_17324\2895423970.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mode()[0], inplace=True)

# %%
#Verify if data has been cleaned properly
print("Total missing values after cleaning:", df.isnull().sum().sum())
df.isnull().sum()[df.isnull().sum() > 0]
# Out:
# Total missing values after cleaning: 0
# Series([], dtype: int64)

# %%
 #Check for null values
 df.notnull()
# Out:
#      surgery   age  hospital_number  rectal_temp  pulse  respiratory_rate  \
# 0       True  True             True         True   True              True
# 1       True  True             True         True   True              True
# 2       True  True             True         True   True              True
# 3       True  True             True         True   True              True
# 4       True  True             True         True   True              True
# ..       ...   ...              ...          ...    ...               ...
# 294     True  True             True         True   True              True
# 295     True  True             True         True   True              True
# 296     True  True             True         True   True              True
# 297     True  True             True         True   True              True
# 298     True  True             True         True   True              True
#
#      temp_of_extremities  peripheral_pulse  mucous_membrane  \
# ...

# %%
# Plot histograms for numeric columns
for col in numeric_cols:
    plt.figure(figsize=(6, 4))
    sns.histplot(df[col], kde=True, bins=30)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()

# %%
#visualisation for categorical columns
for col in categorical_cols:
    plt.figure(figsize=(6, 4))
    sns.countplot(x=df[col])
    plt.title(f'Frequency of {col}')
    plt.xticks(rotation=45)
    plt.xlabel(col)
    plt.ylabel('Count')
    plt.show()

# %%
# Summary stats for numeric columns
for col in numeric_cols:
    print(f" {col}")
    print(f"Mean   : {df[col].mean():.2f}")
    print(f"Median : {df[col].median():.2f}")
    print(f"Mode   : {df[col].mode()[0]}")
    print("-" * 30)
# Out:
#  hospital_number
# Mean   : 1087732.70
# Median : 530301.00
# Mode   : 527544
# ------------------------------
#  rectal_temp
# Mean   : 38.17
# Median : 38.17
# Mode   : 38.16861924686192
# ------------------------------
#  pulse
# Mean   : 72.00
# Median : 68.00
# Mode   : 72.0
# ------------------------------
#  respiratory_rate
# Mean   : 30.46
# Median : 30.00
# Mode   : 30.46058091286307
# ------------------------------
#  packed_cell_volume
# Mean   : 46.31
# Median : 46.00
# Mode   : 46.30740740740741
# ------------------------------
#  total_protein
# Mean   : 24.27
# Median : 7.70
# Mode   : 24.274436090225564
# ------------------------------
#  lesion_1
# Mean   : 3659.71
# Median : 2322.00
# Mode   : 0
# ------------------------------
#  lesion_2
# Mean   : 90.53
# Median : 0.00
# Mode   : 0
# ------------------------------
#  lesion_3
# Mean   : 7.39
# Median : 0.00
# Mode   : 0
# ------------------------------

# %%
# Summary stats for categorical columns
for col in categorical_cols:
    print(f" {col}")
    print(f"Mode : {df[col].mode()[0]}")
    print("-" * 30)
# Out:
#  surgery
# Mode : yes
# ------------------------------
#  age
# Mode : adult
# ------------------------------
#  temp_of_extremities
# Mode : cool
# ------------------------------
#  peripheral_pulse
# Mode : normal
# ------------------------------
#  mucous_membrane
# Mode : normal_pink
# ------------------------------
#  capillary_refill_time
# Mode : less_3_sec
# ------------------------------
#  pain
# Mode : mild_pain
# ------------------------------
#  peristalsis
# Mode : hypomotile
# ------------------------------
#  abdominal_distention
# Mode : none
# ------------------------------
#  nasogastric_tube
# Mode : slight
# ------------------------------
#  nasogastric_reflux
# Mode : none
# ------------------------------
#  rectal_exam_feces
# Mode : absent
# ------------------------------
#  abdomen
# Mode : distend_large
# ------------------------------
#  outcome
# Mode : lived
# ------------------------------
#  surgical_lesion
# Mode : yes
# ------------------------------
# ...

# %%
# Box plots for all numeric columns
for col in numeric_cols:
    plt.figure(figsize=(6, 4))
    sns.boxplot(x=df[col])
    plt.title(f'Box Plot of {col}')
    plt.xlabel(col)
    plt.show()

# %%
# Correlation matrix (numeric only)
corr = df[numeric_cols].corr()

# Heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Matrix")
plt.show()

# %%
#High Positive correlation
sns.scatterplot(data=df, x='pulse', y='respiratory_rate')
plt.title('Pulse vs Respiratory Rate')
plt.show()
np.corrcoef(df["pulse"], df["respiratory_rate"])
# Out:
# array([[1.        , 0.43982468],
#        [0.43982468, 1.        ]])

# %%
#Moderate Positive correlation
sns.scatterplot(data=df, x='rectal_temp', y='pulse')
plt.title('Moderate Positive: rectal_temp vs pulse')
plt.show()
print(np.corrcoef(df['rectal_temp'], df['pulse']))
# Out:
# [[1.         0.20113338]
#  [0.20113338 1.        ]]

# %%
#No correlation
sns.scatterplot(data=df, x='lesion_3', y='pulse')
plt.title('No Correlation: lesion_3 vs pulse')
plt.show()
print(np.corrcoef(df['lesion_3'], df['pulse']))
# Out:
# [[1.         0.10139724]
#  [0.10139724 1.        ]]

# %%
# Moderate Negative Correlation
sns.scatterplot(data=df, x='packed_cell_volume', y='respiratory_rate')
plt.title('Moderate Negative: packed_cell_volume vs respiratory_rate')
plt.show()
print(np.corrcoef(df['packed_cell_volume'], df['respiratory_rate']))
# Out:
# [[1.         0.07379036]
#  [0.07379036 1.        ]]

# %%
# High Negative Correlation
sns.scatterplot(data=df, x='total_protein', y='rectal_temp')
plt.title('High Negative: total_protein vs rectal_temp')
plt.show()
print(np.corrcoef(df['total_protein'], df['rectal_temp']))
# Out:
# [[ 1.         -0.05348725]
#  [-0.05348725  1.        ]]

# %%
# Perfect Negative Correlation(simulated)
df['perfect_neg'] = -df['hospital_number']
sns.scatterplot(data=df, x='hospital_number', y='perfect_neg')
plt.title('Perfect Negative: hospital_number vs perfect_neg')
plt.show()
print(np.corrcoef(df['hospital_number'], df['perfect_neg']))
# Out:
# [[ 1. -1.]
#  [-1.  1.]]

# %%
# Perfect Positive Correlation(simulated)
df['perfect_pos'] = df['hospital_number']            # identical copy
sns.scatterplot(data=df, x='hospital_number', y='perfect_pos')
plt.title('Perfect Positive: hospital_number vs perfect_pos')
plt.show()
print(np.corrcoef(df['hospital_number'], df['perfect_pos']))
# Out:
# [[1. 1.]
#  [1. 1.]]

# %%
#Box plot visualisation of surgery vs pulse
sns.boxplot(x="surgery", y="pulse", data=df)
plt.title("Pulse vs Surgery")
plt.show()

# %%
#Box plot visualisation of peristalsis vs rectal_temp columns
sns.boxplot(x="peristalsis", y="rectal_temp", data=df)
plt.title("Rectal Temp vs Peristalsis")
plt.show()

# %%
#Box plot visualisation of packed cell volume and pain level
sns.boxplot(x="pain", y="packed_cell_volume", data=df)
plt.title("Packed Cell Volume vs Pain Level")
plt.show()

# %%
#pearson correlation coefficient of numerical columns
correlation = df.corr(method='pearson', numeric_only=True)
correlation
# Out:
#                     hospital_number  rectal_temp     pulse  respiratory_rate  \
# hospital_number            1.000000     0.132773  0.347838          0.248315
# rectal_temp                0.132773     1.000000  0.201133          0.239180
# pulse                      0.347838     0.201133  1.000000          0.439825
# respiratory_rate           0.248315     0.239180  0.439825          1.000000
# packed_cell_volume        -0.086868     0.056158  0.369850          0.073790
# total_protein             -0.212407    -0.053487 -0.079947         -0.077715
# lesion_1                   0.145397     0.053031  0.075095          0.152318
# lesion_2                  -0.050433    -0.060428 -0.001897         -0.020553
# lesion_3                  -0.020950     0.029324  0.101397          0.144714
# perfect_neg               -1.000000    -0.132773 -0.347838         -0.248315
# perfect_pos                1.000000     0.132773  0.347838          0.248315
#
# ...

# %%
#Pair plot visualisation of pulse,respiratory rate and rectal_temp columns
selected_vars = ['pulse', 'respiratory_rate', 'rectal_temp']
sns.pairplot(df, vars=selected_vars, kind="reg")
plt.suptitle("Pair Plot with Regression Lines", y=1.02)
plt.show()

# %%
#Pair plot visualisation of pulse,packed cell volume and total protein
selected_vars = ['pulse', 'packed_cell_volume', 'total_protein']
sns.pairplot(df, vars=selected_vars, kind="reg")
plt.suptitle("Pair Plot with Regression Lines", y=1.02)
plt.show()

# %%
#Pair plot visualisation of 'lesion_1', 'lesion_2', 'lesion_3'
selected_vars = ['lesion_1', 'lesion_2', 'lesion_3']
sns.pairplot(df, vars=selected_vars, kind="reg")
plt.suptitle("Pair Plot with Regression Lines", y=1.02)
plt.show()

# %%
#another way of pair plot visualisation without a regression line among 'lesion_1', 'lesion_2', 'lesion_3'
sns.set(style="ticks", color_codes=True)
sns.pairplot(df,height=2,vars = ['lesion_1', 'lesion_2', 'lesion_3'], hue="outcome")
plt.show()

# %%
#another way of pair plot visualisation without a regression line among 'pulse', 'packed_cell_volume', 'total_protein' columns
sns.set(style="ticks", color_codes=True)
sns.pairplot(df,height=2,vars = ['pulse', 'packed_cell_volume', 'total_protein'], hue="outcome")
plt.show()

# %%
#another way of pair plot visualisation without a regression line among 'pulse', 'respiratory_rate', 'rectal_temp' columns
sns.set(style="ticks", color_codes=True)
sns.pairplot(df,height=2,vars =['pulse', 'respiratory_rate', 'rectal_temp'], hue="outcome")
plt.show()

# %%
#Load the necessary package for 1D analysis
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from scipy.stats import chi2_contingency
from mpl_toolkits.mplot3d import Axes3D
import plotly.graph_objects as go

# %%
# Select a numerical column for analysis
num_col = "pulse"

# %%
# Calculate summary statistics
mean_val = df[num_col].mean()
median_val = df[num_col].median()
mode_val = df[num_col].mode().values[0]
skewness_val = df[num_col].skew()
kurtosis_val = df[num_col].kurt()

# %%
# Print summary statistics
print("Summary Statistics:")
print(f"Mean: {mean_val:.2f}")
print(f"Median: {median_val:.2f}")
print(f"Mode: {mode_val:.2f}")
print(f"Skewness: {skewness_val:.2f}")
print(f"Kurtosis: {kurtosis_val:.2f}")
# Out:
# Summary Statistics:
# Mean: 72.00
# Median: 68.00
# Mode: 72.00
# Skewness: 1.06
# Kurtosis: 1.04

# %%
# Weighted Mean
pulse = df['pulse']
weights = np.ones(len(pulse))
weighted_mean = np.average(pulse, weights=weights)
print("Weighted Mean:", weighted_mean)

# Quadratic Mean (Root Mean Square)
quadratic_mean = np.sqrt(np.mean(pulse**2))
print("Quadratic Mean (RMS):", quadratic_mean)

# Harmonic Mean
harmonic_mean = stats.hmean(pulse)
print("Harmonic Mean:", harmonic_mean)

# Geometric Mean
geometric_mean = stats.gmean(pulse)
print("Geometric Mean:", geometric_mean)
# Out:
# Weighted Mean: 72.0
# Quadratic Mean (RMS): 77.04539772781233
# Harmonic Mean: 63.29425530087765
# Geometric Mean: 67.36794424032767

# %%
# Quadratic Mean (Root Mean Square)
quadratic_mean = np.sqrt(np.mean(pulse**2))
print("Quadratic Mean (RMS):", quadratic_mean)

# Harmonic Mean
harmonic_mean = stats.hmean(pulse)
print("Harmonic Mean:", harmonic_mean)

# Geometric Mean
geometric_mean = stats.gmean(pulse)
print("Geometric Mean:", geometric_mean)
# Out:
# Quadratic Mean (RMS): 77.04539772781233
# Harmonic Mean: 63.29425530087765
# Geometric Mean: 67.36794424032767

# %%
# Quartiles
quartiles = pulse.quantile([0.25, 0.5, 0.75])
print("Quartiles:\n", quartiles)

# Deciles
deciles = pulse.quantile(np.arange(0.1, 1.0, 0.1))
print("Deciles:\n", deciles)

# Percentiles
percentiles = pulse.quantile(np.arange(0.01, 1.0, 0.01))
print("Percentiles:\n", percentiles)
# Out:
# Quartiles:
#  0.25    48.5
# 0.50    68.0
# 0.75    88.0
# Name: pulse, dtype: float64
# Deciles:
#  0.1     42.0
# 0.2     48.0
# 0.3     52.0
# 0.4     60.0
# 0.5     68.0
# 0.6     72.0
# 0.7     83.2
# 0.8     93.6
# 0.9    112.0
# Name: pulse, dtype: float64
# Percentiles:
#  0.01     36.00
# 0.02     39.92
# 0.03     40.00
# 0.04     40.00
# 0.05     40.00
#          ...
# 0.95    124.00
# 0.96    129.08
# 0.97    132.24
# 0.98    140.24
# 0.99    150.20
# Name: pulse, Length: 99, dtype: float64

# %%
# Range
range_pulse = pulse.max() - pulse.min()
print("Range:", range_pulse)

# Interquartile Range (IQR)
iqr = stats.iqr(pulse)
print("Interquartile Range (IQR):", iqr)

# Interdecile Range
interdecile_range = deciles.iloc[-1] - deciles.iloc[0]  # 90th - 10th
print("Interdecile Range:", interdecile_range)

# Standard Deviation
std_dev = pulse.std()
print("Standard Deviation:", std_dev)

# Variance
variance = pulse.var()
print("Variance:", variance)
# Out:
# Range: 154.0
# Interquartile Range (IQR): 39.5
# Interdecile Range: 70.0
# Standard Deviation: 27.468468805586706
# Variance: 754.51677852349

# %%
# Frequency Distribution
freq_dist = pulse.value_counts().sort_index()
print("Frequency Distribution:\n", freq_dist)

# Histogram and Frequency Polygon
plt.figure(figsize=(10,5))
counts, bins, patches = plt.hist(pulse, bins=10, edgecolor='black', alpha=0.7)
plt.plot((bins[:-1] + bins[1:]) / 2, counts, marker='o', color='red')  # frequency polygon
plt.title("Histogram & Frequency Polygon of Pulse")
plt.xlabel("Pulse")
plt.ylabel("Frequency")
plt.show()

# Relative Frequency Distribution
rel_freq = freq_dist / freq_dist.sum()
print("Relative Frequency Distribution:\n", rel_freq)

# Pie Chart (categorical bins)
bins = pd.cut(pulse, bins=5)
pie_counts = bins.value_counts()
plt.figure(figsize=(6,6))
plt.pie(pie_counts, labels=pie_counts.index.astype(str), autopct='%1.1f%%', startangle=90)
plt.title("Pulse Distribution Pie Chart")
plt.show()

# Stacked Bar Plot
bar_counts = pd.crosstab(index=bins, columns="count")
bar_counts.plot(kind='bar', stacked=True)
plt.title("Stacked Bar Plot of Pulse")
plt.ylabel("Count")
plt.show()
# Out:
# Frequency Distribution:
#  pulse
# 30.0      2
# 36.0      3
# 38.0      1
# 40.0     18
# 42.0     10
# 44.0     11
# 45.0      2
# 46.0      1
# 48.0     27
# 49.0      1
# 50.0      6
# 52.0     12
# 54.0      7
# 56.0      7
# 60.0     25
# 64.0      8
# 65.0      1
# 66.0      6
# 68.0      5
# 70.0      4
# 72.0     35
# 75.0      1
# 76.0      4
# 78.0      3
# 80.0      8
# 82.0      1
# 84.0      8
# 86.0      3
# 88.0     12
# 90.0      3
# 92.0      4
# 96.0      8
# 98.0      1
# 100.0    11
# 104.0     5
# 108.0     3
# 110.0     1
# 112.0     3
# 114.0     2
# 120.0    10
# 124.0     2
# 128.0     1
# 129.0     1
# 130.0     2
# 132.0     1
# 136.0     1
# 140.0     2
# 146.0     1
# 150.0     2
# 160.0     1
# 164.0     1
# 184.0     1
# Name: count, dtype: int64
# Relative Frequency Distribution:
#  pulse
# 30.0     0.006689
# 36.0     0.010033
# 38.0     0.003344
# 40.0     0.060201
# 42.0     0.033445
# 44.0     0.036789
# 45.0     0.006689
# 46.0     0.003344
# ...

# %%
# Create a skewness plot
plt.figure(figsize=(10, 6))
sns.distplot(df[num_col], kde=False, rug=True)
plt.title("Skewness Plot")
plt.xlabel(num_col)
plt.ylabel("Density")
plt.show()
# Out:
# C:\Users\mukhe\AppData\Local\Temp\ipykernel_17324\3222318452.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[num_col], kde=False, rug=True)

# %%
# Create a kurtosis plot
plt.figure(figsize=(10, 6))
sns.kdeplot(df[num_col], shade=True)
plt.title("Kurtosis Plot")
plt.xlabel(num_col)
plt.ylabel("Density")
plt.show()
# Out:
# C:\Users\mukhe\AppData\Local\Temp\ipykernel_17324\1228107423.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df[num_col], shade=True)

# %%
# Create a histogram with frequency
plt.figure(figsize=(10, 6))
df[num_col].plot.hist(bins=20, edgecolor="black")
plt.title("Frequency Distribution")
plt.xlabel(num_col)
plt.ylabel("Frequency")
plt.show()

# %%
# Create a box plot
plt.figure(figsize=(10, 6))
sns.boxplot(df[num_col])
plt.title("Box Plot")
plt.xlabel(num_col)
plt.show()

# %%
# Create a bar plot
plt.figure(figsize=(10, 6))
df[num_col].value_counts().plot(kind="bar")
plt.title("Bar Plot")
plt.xlabel(num_col)
plt.ylabel("Count")
plt.show()

# %%
# Create a cumulative frequency plot
plt.figure(figsize=(10, 6))
df[num_col].plot(kind="hist", cumulative=True, bins=20, edgecolor="black")
plt.title("Cumulative Frequency Distribution")
plt.xlabel(num_col)
plt.ylabel("Cumulative Frequency")
plt.show()

# %%
# Two-way contingency tables
# Categorical-Categorical
cat_cat = pd.crosstab(df['outcome'], df['mucous_membrane'])
print("Categorical-Categorical Table:\n", cat_cat)
print("Proportions:\n", cat_cat / cat_cat.sum().sum())
# Out:
# Categorical-Categorical Table:
#  mucous_membrane  bright_pink  bright_red  dark_cyanotic  normal_pink  \
# outcome
# died                       8          12             10           17
# euthanized                 2           7              4           13
# lived                     20           6              6           96
#
# mucous_membrane  pale_cyanotic  pale_pink
# outcome
# died                        15         15
# euthanized                  11          7
# lived                       15         35
# Proportions:
#  mucous_membrane  bright_pink  bright_red  dark_cyanotic  normal_pink  \
# outcome
# died                0.026756    0.040134       0.033445     0.056856
# euthanized          0.006689    0.023411       0.013378     0.043478
# lived               0.066890    0.020067       0.020067     0.321070
#
# mucous_membrane  pale_cyanotic  pale_pink
# outcome
# died                  0.050167   0.050167
# euthanized            0.036789   0.023411
# ...

# %%
# Numerical-Numerical (bin numerical columns)
df['pulse_bin'] = pd.qcut(df['pulse'], q=4, labels=False)  # quartiles
df['rectal_temp_bin'] = pd.qcut(df['rectal_temp'], q=4, labels=False)
num_num = pd.crosstab(df['pulse_bin'], df['rectal_temp_bin'])
print("Numerical-Numerical Table (binned):\n", num_num)
print("Proportions:\n", num_num / num_num.sum().sum())
# Out:
# Numerical-Numerical Table (binned):
#  rectal_temp_bin   0   1   2   3
# pulse_bin
# 0                31  16  18  10
# 1                21  23  20  14
# 2                18  36   9  16
# 3                10  22  17  18
# Proportions:
#  rectal_temp_bin         0         1         2         3
# pulse_bin
# 0                0.103679  0.053512  0.060201  0.033445
# 1                0.070234  0.076923  0.066890  0.046823
# 2                0.060201  0.120401  0.030100  0.053512
# 3                0.033445  0.073579  0.056856  0.060201

# %%
# Categorical-Numerical (bin numerical)
cat_num = pd.crosstab(df['outcome'], df['pulse_bin'])
print("Categorical-Numerical Table:\n", cat_num)
print("Proportions:\n", cat_num / cat_num.sum().sum())
# Out:
# Categorical-Numerical Table:
#  pulse_bin    0   1   2   3
# outcome
# died         6  14  31  26
# euthanized   6   8  16  14
# lived       63  56  32  27
# Proportions:
#  pulse_bin          0         1         2         3
# outcome
# died        0.020067  0.046823  0.103679  0.086957
# euthanized  0.020067  0.026756  0.053512  0.046823
# lived       0.210702  0.187291  0.107023  0.090301

# %%
# Three-way contingency table
three_way = pd.crosstab([df['outcome'], df['mucous_membrane']], df['pulse_bin'])
print("Three-way Contingency Table:\n", three_way)
# Out:
# Three-way Contingency Table:
#  pulse_bin                    0   1   2  3
# outcome    mucous_membrane
# died       bright_pink       1   3   2  2
#            bright_red        1   2   6  3
#            dark_cyanotic     0   0   5  5
#            normal_pink       2   5   6  4
#            pale_cyanotic     1   2   4  8
#            pale_pink         1   2   8  4
# euthanized bright_pink       1   1   0  0
#            bright_red        0   1   1  5
#            dark_cyanotic     0   0   2  2
#            normal_pink       4   3   5  1
#            pale_cyanotic     1   1   4  5
#            pale_pink         0   2   4  1
# lived      bright_pink       4   9   4  3
#            bright_red        0   3   3  0
#            dark_cyanotic     0   0   1  5
#            normal_pink      45  27  15  9
#            pale_cyanotic     4   4   0  7
#            pale_pink        10  13   9  3

# %%
# Row/column profiles, relative frequencies, chi-square
row_profiles = cat_cat.div(cat_cat.sum(axis=1), axis=0)
col_profiles = cat_cat.div(cat_cat.sum(axis=0), axis=1)
rel_freq = cat_cat / cat_cat.sum().sum()
chi2, p, dof, expected = chi2_contingency(cat_cat)
independence_ratio = chi2 / cat_cat.sum().sum()
print("Row Profiles:\n", row_profiles)
print("Column Profiles:\n", col_profiles)
print("Relative Frequencies:\n", rel_freq)
print("Chi-square:", chi2, "p-value:", p, "Independence ratio:", independence_ratio)
# Out:
# Row Profiles:
#  mucous_membrane  bright_pink  bright_red  dark_cyanotic  normal_pink  \
# outcome
# died                0.103896    0.155844       0.129870     0.220779
# euthanized          0.045455    0.159091       0.090909     0.295455
# lived               0.112360    0.033708       0.033708     0.539326
#
# mucous_membrane  pale_cyanotic  pale_pink
# outcome
# died                  0.194805   0.194805
# euthanized            0.250000   0.159091
# lived                 0.084270   0.196629
# Column Profiles:
#  mucous_membrane  bright_pink  bright_red  dark_cyanotic  normal_pink  \
# outcome
# died                0.266667        0.48            0.5     0.134921
# euthanized          0.066667        0.28            0.2     0.103175
# lived               0.666667        0.24            0.3     0.761905
#
# mucous_membrane  pale_cyanotic  pale_pink
# outcome
# died                  0.365854   0.263158
# euthanized            0.268293   0.122807
# ...

# %%
# Scatter plot (numerical-numerical)
plt.figure(figsize=(8,6))
sns.scatterplot(x='pulse', y='rectal_temp', hue='outcome', data=df)
plt.title("Pulse vs Rectal Temperature")
plt.show()

# %%
pip install python-ternary
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import ternary
import matplotlib.pyplot as plt
numeric_cols = ['pulse', 'respiratory_rate', 'rectal_temp']
df_numeric = df[numeric_cols]
df_normalized = df_numeric.div(df_numeric.sum(axis=1), axis=0)
# Create ternary plot
scale = 1
figure, tax = ternary.figure(scale=scale)
tax.boundary(linewidth=2.0)
tax.gridlines(color="gray", multiple=0.1)

# Plot points
for _, row in df_normalized.iterrows():
    tax.scatter([(row['pulse'], row['respiratory_rate'], row['rectal_temp'])],
                marker='o', color='red', s=30)

# Set axis labels
tax.left_corner_label("Pulse", fontsize=12)
tax.right_corner_label("Respiratory Rate", fontsize=12)
tax.top_corner_label("Rectal Temp", fontsize=12)

# Ticks and styling
tax.ticks(axis='lbr', multiple=0.1, linewidth=1, fontsize=10)
tax.show()
# Out:
# c:\Users\mukhe\anaconda3\Lib\site-packages\ternary\plotting.py:148: UserWarning: No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
#   ax.scatter(xs, ys, vmin=vmin, vmax=vmax, **kwargs)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
#PERFORMING K-MEANS CLUSTERING
#Using the elbow method to find the optimal number of clusters
X = df.iloc[:, [3, 4]].values
from sklearn.cluster import KMeans
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()
# Out:
# c:\Users\mukhe\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\mukhe\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\mukhe\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# ...

# %%
#Training the K-Means model on the dataset
kmeans = KMeans(n_clusters = 5, init = 'k-means++', random_state = 42)
y_kmeans = kmeans.fit_predict(X)
# Out:
# c:\Users\mukhe\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(

# %%
#Visualising the clusters
plt.scatter(X[y_kmeans == 0, 0], X[y_kmeans == 0, 1], s = 100, c = 'red', label = 'Cluster 1')
plt.scatter(X[y_kmeans == 1, 0], X[y_kmeans == 1, 1], s = 100, c = 'blue', label = 'Cluster 2')
plt.scatter(X[y_kmeans == 2, 0], X[y_kmeans == 2, 1], s = 100, c = 'green', label = 'Cluster 3')
plt.scatter(X[y_kmeans == 3, 0], X[y_kmeans == 3, 1], s = 100, c = 'cyan', label = 'Cluster 4')
plt.scatter(X[y_kmeans == 4, 0], X[y_kmeans == 4, 1], s = 100, c = 'magenta', label = 'Cluster 5')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 300, c = 'yellow', label = 'Centroids')
plt.title('Clusters of horses')
plt.xlabel('pulse')
plt.ylabel('respiratory rate')
plt.legend()
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
X = df[['pulse', 'total_protein']]

# Standardize the two columns directly
scaler = StandardScaler()
scaled_data = scaler.fit_transform(X)

# %%
pca = PCA()
pca_result = pca.fit(scaled_data)

# %%
print("Explained Variance Ratio:")
print(pca.explained_variance_ratio_)
# Out:
# Explained Variance Ratio:
# [0.53997341 0.46002659]

# %%
# Component loadings
loadings = pd.DataFrame(pca.components_, columns=['pulse', 'total_protein'])
print("\nComponent Loadings:")
print(loadings)
# Out:
# Component Loadings:
#       pulse  total_protein
# 0 -0.707107       0.707107
# 1  0.707107       0.707107

# %%
# Scree plot
plt.figure(figsize=(6,4))
plt.plot(range(1, len(pca.explained_variance_ratio_) + 1),
         pca.explained_variance_ratio_, marker='o')
plt.title("Scree Plot")
plt.xlabel("Principal Component")
plt.ylabel("Variance Explained")
plt.grid(True)
plt.show()

# %%
# Importing the necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#We can use the lmplot method from seaborn to see the relationship between Pulse and TotalProtein.
sns.lmplot(x = 'total_protein', y = 'pulse', data = df)

# %%
# Preparing the data
X = df[['pulse']]
y = df[['total_protein']]

# %%
# Splitting the dataset into train and test sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 10)

# %%
#Now the final step is training the linear regression model. From the extremely powerful sklearn library, we import the LinearRegression() function to fit
#our training dataset to the model. When we run LinearRegression().fit(), the function automatically calculates the OLS, which we discussed earlier, and
#generates an appropriate line function:
#Training a Linear Regression Model
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
# Fitting the training data to our model
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
#Model evaluation
#R^2 can be determined using our test dataset in the LinearRegression.score() method:
#check prediction score/accuracy
regressor.score(X_test, y_test)
# Out:
# 0.005019024881257161

# %%
# predict the y values
y_pred=regressor.predict(X_test)
# a data frame with actual and predicted values of y
evaluate = pd.DataFrame({'Actual': y_test.values.flatten(),
'Predicted': y_pred.flatten()})
evaluate.head(10)
# Out:
#    Actual  Predicted
# 0    65.0  24.209539
# 1     7.5  24.016174
# 2    57.0  25.176359
# 3     5.8  22.952671
# 4     7.0  23.146036
# 5     7.3  24.982995
# 6    59.0  24.209539
# 7     7.6  24.741290
# 8    62.0  23.339400
# 9     6.5  23.339400

# %%
#Visualise Actual and Predicted Values
evaluate.head(10).plot(kind = 'bar')
# Out:
# <Axes: >

# %%
#Computing accuracy
# Scoring the model
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
# R2 Score
print(f"R2 score: {r2_score(y_test, y_pred)}")
# Mean Absolute Error (MAE)
print(f"MAE score: {mean_absolute_error(y_test, y_pred)}")
# Mean Squared Error (MSE)
print(f"MSE score: {mean_squared_error(y_test, y_pred)}")
# Out:
# R2 score: 0.005019024881257161
# MAE score: 22.22406571549895
# MSE score: 668.1662464151248
